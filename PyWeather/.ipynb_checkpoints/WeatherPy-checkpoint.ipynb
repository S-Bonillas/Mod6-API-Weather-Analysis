# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\isoro\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\isoro\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 574

# %%
cities
# Out:
# ['muromtsevo',
#  'puerto ayora',
#  'grytviken',
#  'deming',
#  'kirakira',
#  'garoowe',
#  'kapuskasing',
#  'huilong',
#  'funafuti',
#  'chifeng',
#  'hamilton',
#  'waitangi',
#  'tralee',
#  'port moresby',
#  'college',
#  'nushki',
#  "nar'yan-mar",
#  'edinburgh of the seven seas',
#  'atafu village',
#  'baranchinskiy',
#  'adamstown',
#  'stanley',
#  'margaret river',
#  'port-aux-francais',
#  'kushiro',
#  'kirensk',
#  'novyy urengoy',
#  'hermanus',
#  'kitakami',
#  'saint-leu',
#  'anadyr',
#  'kingston',
#  'aasiaat',
#  'puerto natales',
#  'beyneu',
#  "muzayri'",
#  'east london',
#  'badger',
#  'churapcha',
#  'kamloops',
#  'lihue',
#  'taoudenni',
#  'dellys',
#  'coquimbo',
#  'mili',
#  'achinsk',
#  'mariental',
#  'huarmey',
#  'bendale',
#  'marechal candido rondon',
#  'port lincoln',
#  "'ohonua",
#  'brookings',
#  'olonkinbyen',
#  'rio grande',
#  'west island',
#  'yellowknife',
#  'la passe',
#  'bilibino',
#  'umm kaddadah',
#  'samut sakhon',
#  'vilyuchinsk',
#  'khandyga',
#  'ilulissat',
#  'thompson',
#  'ta`u',
#  'lompoc',
#  'portland',
#  'klyuchi',
#  'whitehorse',
#  'fuvahmulah',
#  'dudinka',
#  'alotau',
#  'talnakh',
#  'ushuaia',
#  'carnarvon',
#  'port elizabeth',
#  'sal rei',
#  'palmer',
#  'bethel',
#  'aqadyr',
#  'ostersund',
#  'tomatlan',
#  'olyokminsk',
#  'longyearbyen',
#  'lepsy',
#  'chonchi',
#  'gaoual',
#  'codrington',
#  'bowling green',
#  'leshan',
#  'tiksi',
#  'boende',
#  'hirara',
#  'sitka',
#  'zouerate',
#  'bredasdorp',
#  'kilju',
#  'yeppoon',
#  'colonia',
#  'nizhniy odes',
#  'callao',
#  'yangor',
#  'haiku-pauwela',
#  'albany',
#  'puerto aysen',
#  'ponta delgada',
#  'georgetown',
#  'fortuna',
#  'keflavik',
#  'arevalo',
#  'walvis bay',
#  'sao miguel do araguaia',
#  'san',
#  'san juan de miraflores',
#  'north weeki wachee',
#  'isafjordur',
#  'tura',
#  'le morne-rouge',
#  'chibougamau',
#  'yoichi',
#  'mlowo',
#  'tidjikja',
#  'cartagena',
#  'howrah',
#  'vorgashor',
#  'utrik',
#  'gadzhiyevo',
#  'vize',
#  'kupang',
#  'susuman',
#  'sao geraldo do araguaia',
#  'bayan nur',
#  'taco pozo',
#  'ancud',
#  'takoradi',
#  'puerto varas',
#  'sumbawa besar',
#  'roma',
#  'raseiniai',
#  "ytyk-kyuyel'",
#  'selfoss',
#  'enewetak',
#  'sechura',
#  'ilomantsi',
#  'puerto san carlos',
#  'polyarnyy',
#  'belmonte',
#  'boyolangu',
#  'queenstown',
#  'bargaal',
#  'tanjung pinang',
#  'baikonur',
#  'ghat',
#  'puerto baquerizo moreno',
#  'blackmans bay',
#  'bandiagara',
#  'torbat-e heydariyeh',
#  'natal',
#  'lodwar',
#  'fale old settlement',
#  'jamestown',
#  "ma'rib",
#  'ras gharib',
#  'muynoq',
#  'ghanzi',
#  'dakhla',
#  'ghadamis',
#  'iqaluit',
#  'khovd',
#  'sungho 1-tong',
#  'kodiak',
#  'naklo nad notecia',
#  'tazovsky',
#  'samamea',
#  'timbuktu',
#  'tadine',
#  'kruisfontein',
#  'saint-jorioz',
#  'kununurra',
#  'invercargill',
#  'mudanjiang',
#  'uliastay',
#  'island harbour',
#  'port mathurin',
#  'skwierzyna',
#  'dangriga',
#  'wenshui',
#  'homer',
#  "st. john's",
#  'petropavlovsk-kamchatsky',
#  'afaahiti',
#  'avarua',
#  'wailua homesteads',
#  'smithers',
#  'uturoa',
#  'papatowai',
#  'okha',
#  'acarau',
#  'constantia',
#  'armacao de buzios',
#  'puerto deseado',
#  'shitanjing',
#  'dryden',
#  'yemetsk',
#  'champerico',
#  'pico truncado',
#  'alaghsas',
#  'iskateley',
#  'aykhal',
#  'cuencame de ceniceros',
#  'revda',
#  'ribeira grande',
#  'horizontina',
#  'konarka',
#  'novoaleksandrovsk',
#  'flying fish cove',
#  'dongkan',
#  'san patricio',
#  'abepura',
#  'elko',
#  'san julian',
#  'pucallpa',
#  'itamaraca',
#  'newman',
#  'glennville',
#  'blenheim',
#  'punta arenas',
#  'playa blanca',
#  'udachny',
#  'coahuayana de hidalgo',
#  'devinuwara',
#  'boguchany',
#  'noumea',
#  'espargos',
#  'rio verde de mato grosso',
#  'san luis de la loma',
#  'skiathos',
#  'lima',
#  'mount pearl',
#  'bonthe',
#  'viligili',
#  'bel ombre',
#  'rongelap',
#  'shimla',
#  'beberibe',
#  'ribas do rio pardo',
#  'starkville',
#  'lorengau',
#  'fort bragg',
#  'leibnitz',
#  'touros',
#  'taiohae',
#  'lerwick',
#  'jincheng',
#  'sao jose da coroa grande',
#  'yanjiang',
#  'bohain-en-vermandois',
#  'hithadhoo',
#  'la plata',
#  'chignahuapan',
#  "medvezh'yegorsk",
#  'saint-joseph',
#  'eyl',
#  'havre',
#  'hawaiian paradise park',
#  "n'dalatando",
#  'son la',
#  'jiwani',
#  'mount isa',
#  'kone',
#  'terrace',
#  'rikaze',
#  'saint joseph',
#  'nogliki',
#  'taulaga',
#  'nyurba',
#  'chernyshevskiy',
#  'baro',
#  'tumayr',
#  'weno',
#  'amga',
#  'akhtubinsk',
#  'vershino-darasunskiy',
#  'kurakhovo',
#  'podebrady',
#  'bac lieu',
#  'el nido',
#  'kayyerkan',
#  'aljezur',
#  'san jose de feliciano',
#  'northam',
#  'geraldton',
#  'bardai',
#  'capitan bado',
#  'lata',
#  'lebu',
#  'dubbo',
#  'onguday',
#  'barcelos',
#  'parkville',
#  'happy valley-goose bay',
#  'darnah',
#  'kerema',
#  'kailua-kona',
#  'hasaki',
#  'morondava',
#  'alo',
#  'vorkuta',
#  'shanhecun',
#  'nemuro',
#  'tocopilla',
#  'rockland',
#  'salalah',
#  'nova sintra',
#  'nasiriyah',
#  'manakara',
#  'rabaul',
#  'sagaing',
#  'beni saf',
#  'saidpur',
#  'sterling',
#  'general conesa',
#  'kendari',
#  'valbo',
#  'kavieng',
#  'kehychivka',
#  'ust-nera',
#  'chiredzi',
#  'celestun',
#  'vadso',
#  'port alfred',
#  'vila do maio',
#  'thetford-mines',
#  'constitucion',
#  'abu al matamir',
#  'kannus',
#  'damongo',
#  'viedma',
#  'mosjoen',
#  'manggar',
#  'launceston',
#  'sinan',
#  'butwal',
#  'sao vicente',
#  'yeghegnadzor',
#  'nha trang',
#  'tezu',
#  'bathsheba',
#  'anloga',
#  'alofi',
#  'new norfolk',
#  'pocahontas',
#  'bandar-e lengeh',
#  'kalix',
#  'cargados carajos',
#  'nouna',
#  'eureka',
#  'egilsstadir',
#  'kujang-up',
#  'sinop',
#  'zhongshu',
#  'villa ojo de agua',
#  'nanchang',
#  'qaqortoq',
#  'conde',
#  'rovaniemi',
#  'katabu',
#  'tolanaro',
#  'pacocha',
#  'east ballina',
#  'bushland beach',
#  'san antonio de pale',
#  'praia',
#  'nova vicosa',
#  'madalena',
#  'wajir',
#  'agat village',
#  'popondetta',
#  "la'ie",
#  'toga village',
#  'namibe',
#  'murun-kuren',
#  "yelan'",
#  'tranovaho',
#  'kimbe',
#  'cabo san lucas',
#  'greenville',
#  'montrose',
#  'tanki leendert',
#  'ouddorp',
#  'saipan',
#  'hotan',
#  'bengkulu',
#  'gasa',
#  'al kharijah',
#  'al jubayl',
#  'howard springs',
#  'tuy hoa',
#  'karratha',
#  'huaidian',
#  'glace bay',
#  'san andres',
#  'capayan',
#  'ola',
#  'porkhov',
#  'la ronge',
#  'ribeira brava',
#  'mirnyy',
#  'bandarbeyla',
#  'stjordalshalsen',
#  'sisimiut',
#  'lakota',
#  'djenne',
#  'suai',
#  'dapa',
#  'at-bashi',
#  "kapa'a",
#  'sampit',
#  'sonsorol village',
#  'bandar lampung',
#  'los andes',
#  'ornskoldsvik',
#  'masuguru',
#  'bratslav',
#  'nagqu',
#  'buncrana',
#  'hadibu',
#  'ekibastuz',
#  'santa ana',
#  'diboll',
#  'forster',
#  'fenoarivo be',
#  'sinabang',
#  'fujin',
#  'mersing',
#  'progreso',
#  'arraial do cabo',
#  'pisco',
#  'necochea',
#  'fuling',
#  'temryuk',
#  'trujillo',
#  'fisterra',
#  'parauapebas',
#  'eraan',
#  'donghai',
#  'woolgoolga',
#  'manas',
#  "port saint john's",
#  'salekhard',
#  'livny',
#  'igrim',
#  'lutes mountain',
#  'collie',
#  'magadan',
#  'stephenville',
#  'mejit',
#  'bonnyville',
#  'dawson creek',
#  'tokoname',
#  'dzuunmod',
#  'karakecili',
#  'coari',
#  'woodend',
#  'melekeok village',
#  'zaysan',
#  'birzebbuga',
#  "parabel'",
#  'sosnovka',
#  'auki',
#  'mesyagutovo',
#  'el granada',
#  'troitskiy',
#  'itaituba',
#  'kavalerovo',
#  'xiaoweizhai',
#  'los banos',
#  'cable beach',
#  'lexington park',
#  'ippy',
#  'ohara',
#  'shakawe',
#  'lucapa',
#  'hammerfest',
#  'puerto santa',
#  'prince rupert',
#  'urangan',
#  'gaspe',
#  'mizque',
#  'margate',
#  'yinchuan',
#  'vingt cinq',
#  'severo-yeniseyskiy',
#  'yelizovo',
#  'quillacollo',
#  'birao',
#  'big bend',
#  'dampit',
#  'sakakah',
#  'antofagasta',
#  'kyzyl-suu',
#  'albertina',
#  'kasungu',
#  'whakatane',
#  'flen',
#  'bainbridge',
#  'padang',
#  'igarka',
#  'armagh',
#  'puerto yuca',
#  'singaraja',
#  'poltavka',
#  'ciudad miguel aleman',
#  'trapani',
#  'pombas',
#  'maintirano',
#  'kristiansund',
#  'calama',
#  'anicuns',
#  'chapaev',
#  "'ain benian",
#  'shingu',
#  'tangalle',
#  'el alto',
#  'priozersk',
#  'sandnessjoen',
#  'man',
#  'tanumah',
#  'katima mulilo',
#  'quellon',
#  'dunkirk',
#  'jardinopolis',
#  'kapit',
#  'tuineje',
#  'chicxulub puerto',
#  'juegang',
#  'argo',
#  'qinggang',
#  'changping',
#  'pekalongan',
#  'alice springs',
#  'aswan',
#  'gizycko',
#  'yazman',
#  'cannonvale',
#  'nouadhibou',
#  'el abiodh sidi cheikh',
#  'lionel town',
#  'richards bay',
#  'penedo',
#  'san juan',
#  'stara syniava',
#  'nadym',
#  'enshi',
#  'yuzhno-kurilsk',
#  'lhokseumawe',
#  'brasileia',
#  'chimore',
#  'pariaman',
#  'dalbandin',
#  'am djarass',
#  'saint-pierre',
#  'valparaiso',
#  'tual',
#  'little cayman',
#  'freetown',
#  'ambovombe',
#  'hilo',
#  'akureyri',
#  'salinas',
#  "ji'an",
#  'amargosa',
#  'narasannapeta']

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | muromtsevo
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | deming
# Processing Record 5 of Set 1 | kirakira
# Processing Record 6 of Set 1 | garoowe
# Processing Record 7 of Set 1 | kapuskasing
# Processing Record 8 of Set 1 | huilong
# Processing Record 9 of Set 1 | funafuti
# Processing Record 10 of Set 1 | chifeng
# Processing Record 11 of Set 1 | hamilton
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | tralee
# Processing Record 14 of Set 1 | port moresby
# Processing Record 15 of Set 1 | college
# Processing Record 16 of Set 1 | nushki
# Processing Record 17 of Set 1 | nar'yan-mar
# Processing Record 18 of Set 1 | edinburgh of the seven seas
# Processing Record 19 of Set 1 | atafu village
# Processing Record 20 of Set 1 | baranchinskiy
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | stanley
# Processing Record 23 of Set 1 | margaret river
# Processing Record 24 of Set 1 | port-aux-francais
# Processing Record 25 of Set 1 | kushiro
# Processing Record 26 of Set 1 | kirensk
# Processing Record 27 of Set 1 | novyy urengoy
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | kitakami
# Processing Record 30 of Set 1 | saint-leu
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | kingston
# Processing Record 33 of Set 1 | aasiaat
# Processing Record 34 of Set 1 | puerto natales
# Processing Record 35 of Set 1 | beyneu
# Processing Record 36 of Set 1 | muzayri'
# City not found. Skipping...
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | badger
# Processing Record 39 of Set 1 | churapcha
# Processing Record 40 of Set 1 | kamloops
# Processing Record 41 of Set 1 | lihue
# Processing Record 42 of Set 1 | taoudenni
# Processing Record 43 of Set 1 | dellys
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | mili
# Processing Record 46 of Set 1 | achinsk
# Processing Record 47 of Set 1 | mariental
# Processing Record 48 of Set 1 | huarmey
# Processing Record 49 of Set 1 | bendale
# Processing Record 50 of Set 1 | marechal candido rondon
# Processing Record 0 of Set 2 | port lincoln
# Processing Record 1 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 2 of Set 2 | brookings
# Processing Record 3 of Set 2 | olonkinbyen
# Processing Record 4 of Set 2 | rio grande
# Processing Record 5 of Set 2 | west island
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | la passe
# Processing Record 8 of Set 2 | bilibino
# Processing Record 9 of Set 2 | umm kaddadah
# Processing Record 10 of Set 2 | samut sakhon
# Processing Record 11 of Set 2 | vilyuchinsk
# Processing Record 12 of Set 2 | khandyga
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | ta`u
# Processing Record 16 of Set 2 | lompoc
# Processing Record 17 of Set 2 | portland
# Processing Record 18 of Set 2 | klyuchi
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 2 | talnakh
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | sal rei
# Processing Record 28 of Set 2 | palmer
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | aqadyr
# Processing Record 31 of Set 2 | ostersund
# Processing Record 32 of Set 2 | tomatlan
# Processing Record 33 of Set 2 | olyokminsk
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | lepsy
# Processing Record 36 of Set 2 | chonchi
# Processing Record 37 of Set 2 | gaoual
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | bowling green
# Processing Record 40 of Set 2 | leshan
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | boende
# Processing Record 43 of Set 2 | hirara
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | zouerate
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | kilju
# Processing Record 48 of Set 2 | yeppoon
# Processing Record 49 of Set 2 | colonia
# Processing Record 0 of Set 3 | nizhniy odes
# Processing Record 1 of Set 3 | callao
# Processing Record 2 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 3 of Set 3 | haiku-pauwela
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | puerto aysen
# Processing Record 6 of Set 3 | ponta delgada
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | keflavik
# Processing Record 10 of Set 3 | arevalo
# Processing Record 11 of Set 3 | walvis bay
# Processing Record 12 of Set 3 | sao miguel do araguaia
# Processing Record 13 of Set 3 | san
# Processing Record 14 of Set 3 | san juan de miraflores
# Processing Record 15 of Set 3 | north weeki wachee
# Processing Record 16 of Set 3 | isafjordur
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | le morne-rouge
# Processing Record 19 of Set 3 | chibougamau
# Processing Record 20 of Set 3 | yoichi
# Processing Record 21 of Set 3 | mlowo
# Processing Record 22 of Set 3 | tidjikja
# Processing Record 23 of Set 3 | cartagena
# Processing Record 24 of Set 3 | howrah
# Processing Record 25 of Set 3 | vorgashor
# Processing Record 26 of Set 3 | utrik
# Processing Record 27 of Set 3 | gadzhiyevo
# Processing Record 28 of Set 3 | vize
# Processing Record 29 of Set 3 | kupang
# Processing Record 30 of Set 3 | susuman
# Processing Record 31 of Set 3 | sao geraldo do araguaia
# Processing Record 32 of Set 3 | bayan nur
# City not found. Skipping...
# Processing Record 33 of Set 3 | taco pozo
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | puerto varas
# Processing Record 37 of Set 3 | sumbawa besar
# Processing Record 38 of Set 3 | roma
# Processing Record 39 of Set 3 | raseiniai
# Processing Record 40 of Set 3 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 41 of Set 3 | selfoss
# Processing Record 42 of Set 3 | enewetak
# Processing Record 43 of Set 3 | sechura
# Processing Record 44 of Set 3 | ilomantsi
# Processing Record 45 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 3 | polyarnyy
# Processing Record 47 of Set 3 | belmonte
# Processing Record 48 of Set 3 | boyolangu
# Processing Record 49 of Set 3 | queenstown
# Processing Record 0 of Set 4 | bargaal
# Processing Record 1 of Set 4 | tanjung pinang
# Processing Record 2 of Set 4 | baikonur
# Processing Record 3 of Set 4 | ghat
# Processing Record 4 of Set 4 | puerto baquerizo moreno
# Processing Record 5 of Set 4 | blackmans bay
# Processing Record 6 of Set 4 | bandiagara
# Processing Record 7 of Set 4 | torbat-e heydariyeh
# Processing Record 8 of Set 4 | natal
# Processing Record 9 of Set 4 | lodwar
# Processing Record 10 of Set 4 | fale old settlement
# Processing Record 11 of Set 4 | jamestown
# Processing Record 12 of Set 4 | ma'rib
# Processing Record 13 of Set 4 | ras gharib
# City not found. Skipping...
# Processing Record 14 of Set 4 | muynoq
# Processing Record 15 of Set 4 | ghanzi
# Processing Record 16 of Set 4 | dakhla
# Processing Record 17 of Set 4 | ghadamis
# Processing Record 18 of Set 4 | iqaluit
# Processing Record 19 of Set 4 | khovd
# Processing Record 20 of Set 4 | sungho 1-tong
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | naklo nad notecia
# Processing Record 23 of Set 4 | tazovsky
# Processing Record 24 of Set 4 | samamea
# City not found. Skipping...
# Processing Record 25 of Set 4 | timbuktu
# Processing Record 26 of Set 4 | tadine
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | saint-jorioz
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | invercargill
# Processing Record 31 of Set 4 | mudanjiang
# Processing Record 32 of Set 4 | uliastay
# Processing Record 33 of Set 4 | island harbour
# Processing Record 34 of Set 4 | port mathurin
# Processing Record 35 of Set 4 | skwierzyna
# Processing Record 36 of Set 4 | dangriga
# Processing Record 37 of Set 4 | wenshui
# Processing Record 38 of Set 4 | homer
# Processing Record 39 of Set 4 | st. john's
# Processing Record 40 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 4 | afaahiti
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | wailua homesteads
# Processing Record 44 of Set 4 | smithers
# Processing Record 45 of Set 4 | uturoa
# Processing Record 46 of Set 4 | papatowai
# Processing Record 47 of Set 4 | okha
# Processing Record 48 of Set 4 | acarau
# Processing Record 49 of Set 4 | constantia
# Processing Record 0 of Set 5 | armacao de buzios
# Processing Record 1 of Set 5 | puerto deseado
# Processing Record 2 of Set 5 | shitanjing
# Processing Record 3 of Set 5 | dryden
# Processing Record 4 of Set 5 | yemetsk
# Processing Record 5 of Set 5 | champerico
# Processing Record 6 of Set 5 | pico truncado
# Processing Record 7 of Set 5 | alaghsas
# Processing Record 8 of Set 5 | iskateley
# Processing Record 9 of Set 5 | aykhal
# Processing Record 10 of Set 5 | cuencame de ceniceros
# Processing Record 11 of Set 5 | revda
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | horizontina
# Processing Record 14 of Set 5 | konarka
# Processing Record 15 of Set 5 | novoaleksandrovsk
# Processing Record 16 of Set 5 | flying fish cove
# Processing Record 17 of Set 5 | dongkan
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | abepura
# Processing Record 20 of Set 5 | elko
# Processing Record 21 of Set 5 | san julian
# Processing Record 22 of Set 5 | pucallpa
# Processing Record 23 of Set 5 | itamaraca
# Processing Record 24 of Set 5 | newman
# Processing Record 25 of Set 5 | glennville
# Processing Record 26 of Set 5 | blenheim
# Processing Record 27 of Set 5 | punta arenas
# Processing Record 28 of Set 5 | playa blanca
# Processing Record 29 of Set 5 | udachny
# Processing Record 30 of Set 5 | coahuayana de hidalgo
# Processing Record 31 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 32 of Set 5 | boguchany
# Processing Record 33 of Set 5 | noumea
# Processing Record 34 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 35 of Set 5 | rio verde de mato grosso
# Processing Record 36 of Set 5 | san luis de la loma
# Processing Record 37 of Set 5 | skiathos
# Processing Record 38 of Set 5 | lima
# Processing Record 39 of Set 5 | mount pearl
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 5 | bel ombre
# Processing Record 43 of Set 5 | rongelap
# Processing Record 44 of Set 5 | shimla
# Processing Record 45 of Set 5 | beberibe
# Processing Record 46 of Set 5 | ribas do rio pardo
# Processing Record 47 of Set 5 | starkville
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | fort bragg
# Processing Record 0 of Set 6 | leibnitz
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | taiohae
# City not found. Skipping...
# Processing Record 3 of Set 6 | lerwick
# Processing Record 4 of Set 6 | jincheng
# Processing Record 5 of Set 6 | sao jose da coroa grande
# Processing Record 6 of Set 6 | yanjiang
# Processing Record 7 of Set 6 | bohain-en-vermandois
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | la plata
# Processing Record 10 of Set 6 | chignahuapan
# Processing Record 11 of Set 6 | medvezh'yegorsk
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | eyl
# Processing Record 14 of Set 6 | havre
# Processing Record 15 of Set 6 | hawaiian paradise park
# Processing Record 16 of Set 6 | n'dalatando
# Processing Record 17 of Set 6 | son la
# Processing Record 18 of Set 6 | jiwani
# Processing Record 19 of Set 6 | mount isa
# Processing Record 20 of Set 6 | kone
# Processing Record 21 of Set 6 | terrace
# Processing Record 22 of Set 6 | rikaze
# Processing Record 23 of Set 6 | saint joseph
# Processing Record 24 of Set 6 | nogliki
# Processing Record 25 of Set 6 | taulaga
# Processing Record 26 of Set 6 | nyurba
# Processing Record 27 of Set 6 | chernyshevskiy
# Processing Record 28 of Set 6 | baro
# Processing Record 29 of Set 6 | tumayr
# Processing Record 30 of Set 6 | weno
# Processing Record 31 of Set 6 | amga
# Processing Record 32 of Set 6 | akhtubinsk
# Processing Record 33 of Set 6 | vershino-darasunskiy
# Processing Record 34 of Set 6 | kurakhovo
# Processing Record 35 of Set 6 | podebrady
# Processing Record 36 of Set 6 | bac lieu
# Processing Record 37 of Set 6 | el nido
# Processing Record 38 of Set 6 | kayyerkan
# Processing Record 39 of Set 6 | aljezur
# Processing Record 40 of Set 6 | san jose de feliciano
# Processing Record 41 of Set 6 | northam
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | bardai
# Processing Record 44 of Set 6 | capitan bado
# Processing Record 45 of Set 6 | lata
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | dubbo
# Processing Record 48 of Set 6 | onguday
# Processing Record 49 of Set 6 | barcelos
# Processing Record 0 of Set 7 | parkville
# Processing Record 1 of Set 7 | happy valley-goose bay
# Processing Record 2 of Set 7 | darnah
# Processing Record 3 of Set 7 | kerema
# Processing Record 4 of Set 7 | kailua-kona
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | morondava
# Processing Record 7 of Set 7 | alo
# Processing Record 8 of Set 7 | vorkuta
# Processing Record 9 of Set 7 | shanhecun
# Processing Record 10 of Set 7 | nemuro
# Processing Record 11 of Set 7 | tocopilla
# Processing Record 12 of Set 7 | rockland
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | nova sintra
# Processing Record 15 of Set 7 | nasiriyah
# Processing Record 16 of Set 7 | manakara
# Processing Record 17 of Set 7 | rabaul
# Processing Record 18 of Set 7 | sagaing
# Processing Record 19 of Set 7 | beni saf
# Processing Record 20 of Set 7 | saidpur
# Processing Record 21 of Set 7 | sterling
# Processing Record 22 of Set 7 | general conesa
# Processing Record 23 of Set 7 | kendari
# Processing Record 24 of Set 7 | valbo
# Processing Record 25 of Set 7 | kavieng
# Processing Record 26 of Set 7 | kehychivka
# Processing Record 27 of Set 7 | ust-nera
# Processing Record 28 of Set 7 | chiredzi
# Processing Record 29 of Set 7 | celestun
# Processing Record 30 of Set 7 | vadso
# Processing Record 31 of Set 7 | port alfred
# Processing Record 32 of Set 7 | vila do maio
# Processing Record 33 of Set 7 | thetford-mines
# Processing Record 34 of Set 7 | constitucion
# Processing Record 35 of Set 7 | abu al matamir
# Processing Record 36 of Set 7 | kannus
# Processing Record 37 of Set 7 | damongo
# City not found. Skipping...
# Processing Record 38 of Set 7 | viedma
# Processing Record 39 of Set 7 | mosjoen
# Processing Record 40 of Set 7 | manggar
# Processing Record 41 of Set 7 | launceston
# Processing Record 42 of Set 7 | sinan
# Processing Record 43 of Set 7 | butwal
# Processing Record 44 of Set 7 | sao vicente
# Processing Record 45 of Set 7 | yeghegnadzor
# Processing Record 46 of Set 7 | nha trang
# Processing Record 47 of Set 7 | tezu
# Processing Record 48 of Set 7 | bathsheba
# Processing Record 49 of Set 7 | anloga
# Processing Record 0 of Set 8 | alofi
# Processing Record 1 of Set 8 | new norfolk
# Processing Record 2 of Set 8 | pocahontas
# Processing Record 3 of Set 8 | bandar-e lengeh
# Processing Record 4 of Set 8 | kalix
# Processing Record 5 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 8 | nouna
# Processing Record 7 of Set 8 | eureka
# Processing Record 8 of Set 8 | egilsstadir
# Processing Record 9 of Set 8 | kujang-up
# Processing Record 10 of Set 8 | sinop
# Processing Record 11 of Set 8 | zhongshu
# Processing Record 12 of Set 8 | villa ojo de agua
# Processing Record 13 of Set 8 | nanchang
# Processing Record 14 of Set 8 | qaqortoq
# Processing Record 15 of Set 8 | conde
# Processing Record 16 of Set 8 | rovaniemi
# Processing Record 17 of Set 8 | katabu
# Processing Record 18 of Set 8 | tolanaro
# Processing Record 19 of Set 8 | pacocha
# Processing Record 20 of Set 8 | east ballina
# Processing Record 21 of Set 8 | bushland beach
# City not found. Skipping...
# Processing Record 22 of Set 8 | san antonio de pale
# Processing Record 23 of Set 8 | praia
# Processing Record 24 of Set 8 | nova vicosa
# Processing Record 25 of Set 8 | madalena
# Processing Record 26 of Set 8 | wajir
# Processing Record 27 of Set 8 | agat village
# Processing Record 28 of Set 8 | popondetta
# Processing Record 29 of Set 8 | la'ie
# Processing Record 30 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 31 of Set 8 | namibe
# Processing Record 32 of Set 8 | murun-kuren
# Processing Record 33 of Set 8 | yelan'
# Processing Record 34 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 35 of Set 8 | kimbe
# Processing Record 36 of Set 8 | cabo san lucas
# Processing Record 37 of Set 8 | greenville
# Processing Record 38 of Set 8 | montrose
# Processing Record 39 of Set 8 | tanki leendert
# City not found. Skipping...
# Processing Record 40 of Set 8 | ouddorp
# Processing Record 41 of Set 8 | saipan
# Processing Record 42 of Set 8 | hotan
# Processing Record 43 of Set 8 | bengkulu
# Processing Record 44 of Set 8 | gasa
# Processing Record 45 of Set 8 | al kharijah
# Processing Record 46 of Set 8 | al jubayl
# Processing Record 47 of Set 8 | howard springs
# Processing Record 48 of Set 8 | tuy hoa
# Processing Record 49 of Set 8 | karratha
# Processing Record 0 of Set 9 | huaidian
# Processing Record 1 of Set 9 | glace bay
# Processing Record 2 of Set 9 | san andres
# Processing Record 3 of Set 9 | capayan
# Processing Record 4 of Set 9 | ola
# Processing Record 5 of Set 9 | porkhov
# Processing Record 6 of Set 9 | la ronge
# Processing Record 7 of Set 9 | ribeira brava
# Processing Record 8 of Set 9 | mirnyy
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | stjordalshalsen
# Processing Record 11 of Set 9 | sisimiut
# Processing Record 12 of Set 9 | lakota
# Processing Record 13 of Set 9 | djenne
# Processing Record 14 of Set 9 | suai
# City not found. Skipping...
# Processing Record 15 of Set 9 | dapa
# Processing Record 16 of Set 9 | at-bashi
# Processing Record 17 of Set 9 | kapa'a
# Processing Record 18 of Set 9 | sampit
# Processing Record 19 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 20 of Set 9 | bandar lampung
# Processing Record 21 of Set 9 | los andes
# Processing Record 22 of Set 9 | ornskoldsvik
# Processing Record 23 of Set 9 | masuguru
# Processing Record 24 of Set 9 | bratslav
# Processing Record 25 of Set 9 | nagqu
# Processing Record 26 of Set 9 | buncrana
# Processing Record 27 of Set 9 | hadibu
# Processing Record 28 of Set 9 | ekibastuz
# Processing Record 29 of Set 9 | santa ana
# Processing Record 30 of Set 9 | diboll
# Processing Record 31 of Set 9 | forster
# Processing Record 32 of Set 9 | fenoarivo be
# Processing Record 33 of Set 9 | sinabang
# Processing Record 34 of Set 9 | fujin
# Processing Record 35 of Set 9 | mersing
# Processing Record 36 of Set 9 | progreso
# Processing Record 37 of Set 9 | arraial do cabo
# Processing Record 38 of Set 9 | pisco
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | fuling
# Processing Record 41 of Set 9 | temryuk
# Processing Record 42 of Set 9 | trujillo
# Processing Record 43 of Set 9 | fisterra
# Processing Record 44 of Set 9 | parauapebas
# Processing Record 45 of Set 9 | eraan
# Processing Record 46 of Set 9 | donghai
# Processing Record 47 of Set 9 | woolgoolga
# Processing Record 48 of Set 9 | manas
# Processing Record 49 of Set 9 | port saint john's
# Processing Record 0 of Set 10 | salekhard
# Processing Record 1 of Set 10 | livny
# Processing Record 2 of Set 10 | igrim
# Processing Record 3 of Set 10 | lutes mountain
# City not found. Skipping...
# Processing Record 4 of Set 10 | collie
# Processing Record 5 of Set 10 | magadan
# Processing Record 6 of Set 10 | stephenville
# Processing Record 7 of Set 10 | mejit
# Processing Record 8 of Set 10 | bonnyville
# Processing Record 9 of Set 10 | dawson creek
# Processing Record 10 of Set 10 | tokoname
# Processing Record 11 of Set 10 | dzuunmod
# Processing Record 12 of Set 10 | karakecili
# Processing Record 13 of Set 10 | coari
# Processing Record 14 of Set 10 | woodend
# Processing Record 15 of Set 10 | melekeok village
# Processing Record 16 of Set 10 | zaysan
# Processing Record 17 of Set 10 | birzebbuga
# Processing Record 18 of Set 10 | parabel'
# Processing Record 19 of Set 10 | sosnovka
# Processing Record 20 of Set 10 | auki
# Processing Record 21 of Set 10 | mesyagutovo
# Processing Record 22 of Set 10 | el granada
# Processing Record 23 of Set 10 | troitskiy
# Processing Record 24 of Set 10 | itaituba
# Processing Record 25 of Set 10 | kavalerovo
# Processing Record 26 of Set 10 | xiaoweizhai
# Processing Record 27 of Set 10 | los banos
# Processing Record 28 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 29 of Set 10 | lexington park
# Processing Record 30 of Set 10 | ippy
# Processing Record 31 of Set 10 | ohara
# Processing Record 32 of Set 10 | shakawe
# Processing Record 33 of Set 10 | lucapa
# Processing Record 34 of Set 10 | hammerfest
# Processing Record 35 of Set 10 | puerto santa
# Processing Record 36 of Set 10 | prince rupert
# Processing Record 37 of Set 10 | urangan
# Processing Record 38 of Set 10 | gaspe
# Processing Record 39 of Set 10 | mizque
# Processing Record 40 of Set 10 | margate
# Processing Record 41 of Set 10 | yinchuan
# Processing Record 42 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 43 of Set 10 | severo-yeniseyskiy
# Processing Record 44 of Set 10 | yelizovo
# Processing Record 45 of Set 10 | quillacollo
# Processing Record 46 of Set 10 | birao
# Processing Record 47 of Set 10 | big bend
# Processing Record 48 of Set 10 | dampit
# Processing Record 49 of Set 10 | sakakah
# Processing Record 0 of Set 11 | antofagasta
# Processing Record 1 of Set 11 | kyzyl-suu
# Processing Record 2 of Set 11 | albertina
# Processing Record 3 of Set 11 | kasungu
# Processing Record 4 of Set 11 | whakatane
# Processing Record 5 of Set 11 | flen
# Processing Record 6 of Set 11 | bainbridge
# Processing Record 7 of Set 11 | padang
# Processing Record 8 of Set 11 | igarka
# Processing Record 9 of Set 11 | armagh
# Processing Record 10 of Set 11 | puerto yuca
# Processing Record 11 of Set 11 | singaraja
# Processing Record 12 of Set 11 | poltavka
# Processing Record 13 of Set 11 | ciudad miguel aleman
# Processing Record 14 of Set 11 | trapani
# Processing Record 15 of Set 11 | pombas
# Processing Record 16 of Set 11 | maintirano
# Processing Record 17 of Set 11 | kristiansund
# Processing Record 18 of Set 11 | calama
# Processing Record 19 of Set 11 | anicuns
# Processing Record 20 of Set 11 | chapaev
# Processing Record 21 of Set 11 | 'ain benian
# Processing Record 22 of Set 11 | shingu
# Processing Record 23 of Set 11 | tangalle
# Processing Record 24 of Set 11 | el alto
# Processing Record 25 of Set 11 | priozersk
# Processing Record 26 of Set 11 | sandnessjoen
# Processing Record 27 of Set 11 | man
# Processing Record 28 of Set 11 | tanumah
# Processing Record 29 of Set 11 | katima mulilo
# Processing Record 30 of Set 11 | quellon
# Processing Record 31 of Set 11 | dunkirk
# Processing Record 32 of Set 11 | jardinopolis
# Processing Record 33 of Set 11 | kapit
# Processing Record 34 of Set 11 | tuineje
# Processing Record 35 of Set 11 | chicxulub puerto
# City not found. Skipping...
# Processing Record 36 of Set 11 | juegang
# Processing Record 37 of Set 11 | argo
# Processing Record 38 of Set 11 | qinggang
# Processing Record 39 of Set 11 | changping
# Processing Record 40 of Set 11 | pekalongan
# Processing Record 41 of Set 11 | alice springs
# Processing Record 42 of Set 11 | aswan
# Processing Record 43 of Set 11 | gizycko
# Processing Record 44 of Set 11 | yazman
# Processing Record 45 of Set 11 | cannonvale
# Processing Record 46 of Set 11 | nouadhibou
# Processing Record 47 of Set 11 | el abiodh sidi cheikh
# Processing Record 48 of Set 11 | lionel town
# Processing Record 49 of Set 11 | richards bay
# Processing Record 0 of Set 12 | penedo
# Processing Record 1 of Set 12 | san juan
# Processing Record 2 of Set 12 | stara syniava
# Processing Record 3 of Set 12 | nadym
# Processing Record 4 of Set 12 | enshi
# Processing Record 5 of Set 12 | yuzhno-kurilsk
# Processing Record 6 of Set 12 | lhokseumawe
# Processing Record 7 of Set 12 | brasileia
# Processing Record 8 of Set 12 | chimore
# Processing Record 9 of Set 12 | pariaman
# Processing Record 10 of Set 12 | dalbandin
# Processing Record 11 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 12 of Set 12 | saint-pierre
# Processing Record 13 of Set 12 | valparaiso
# Processing Record 14 of Set 12 | tual
# Processing Record 15 of Set 12 | little cayman
# City not found. Skipping...
# Processing Record 16 of Set 12 | freetown
# Processing Record 17 of Set 12 | ambovombe
# Processing Record 18 of Set 12 | hilo
# Processing Record 19 of Set 12 | akureyri
# Processing Record 20 of Set 12 | salinas
# Processing Record 21 of Set 12 | ji'an
# Processing Record 22 of Set 12 | amargosa
# Processing Record 23 of Set 12 | narasannapeta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# # Show Record Count
city_data_df.count()
# Out:
# City          546
# Lat           546
# Lng           546
# Max Temp      546
# Humidity      546
# Cloudiness    546
# Wind Speed    546
# Country       546
# Date          546
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    muromtsevo  56.3724   75.2418     10.30        82          11
# 1  puerto ayora  -0.7393  -90.3518     23.64        95          72
# 2     grytviken -54.2811  -36.5092     -1.52        96         100
# 3        deming  32.2687 -107.7586     32.94        16           0
# 4      kirakira -10.4544  161.9205     28.12        74          97
#
#    Wind Speed Country        Date
# 0        2.96      RU  1694312221
# 1        3.65      EC  1694312133
# 2        4.37      GS  1694312221
# 3        6.69      US  1694312222
# 4        5.10      SB  1694312222

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Resources/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("Resources/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          muromtsevo  56.3724   75.2418     10.30        82          11
# 1        puerto ayora  -0.7393  -90.3518     23.64        95          72
# 2           grytviken -54.2811  -36.5092     -1.52        96         100
# 3              deming  32.2687 -107.7586     32.94        16           0
# 4            kirakira -10.4544  161.9205     28.12        74          97
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      RU  1694312221
# 1              3.65      EC  1694312133
# 2              4.37      GS  1694312221
# 3              6.69      US  1694312222
# 4              5.10      SB  1694312222

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="red",
    linewidths=.5,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("Resources/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="yellow",
    linewidths=.5,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Resources/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="gray",
    linewidths=.5,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Resources/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="green",
    linewidths=.5,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("Resources/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):
        
    # Linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         muromtsevo  56.3724   75.2418     10.30        82          11
# 3             deming  32.2687 -107.7586     32.94        16           0
# 5            garoowe   8.4054   48.4845     24.62        61           6
# 6        kapuskasing  49.4169  -82.4331     13.05        88          20
# 7            huilong  31.8111  121.6550     27.25        62           4
#
#          Wind Speed Country        Date
# City_ID
# 0              2.96      RU  1694312221
# 3              6.69      US  1694312222
# 5              8.33      SO  1694312222
# 6              1.54      CA  1694311966
# 7              4.11      CN  1694312223

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        puerto ayora  -0.7393  -90.3518     23.64        95          72
# 2           grytviken -54.2811  -36.5092     -1.52        96         100
# 4            kirakira -10.4544  161.9205     28.12        74          97
# 8            funafuti  -8.5243  179.1942     31.00        79          75
# 11           waitangi -43.9535 -176.5597     12.12        84         100
#
#          Wind Speed Country        Date
# City_ID
# 1              3.65      EC  1694312133
# 2              4.37      GS  1694312221
# 4              5.10      SB  1694312222
# 8              0.00      TV  1694312223
# 11             3.13      NZ  1694312223

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (0, 0))
# Out:
# The r-value is 0.6296377859773928

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-20, 0))
# Out:
# The r-value is 0.6336501704212089

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (48, 15))
# Out:
# The r-value is 0.005645250915951427

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-56, 10))
# Out:
# The r-value is 3.2191564897052344e-05

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (53, 46))
# Out:
# The r-value is 0.002156604643174599

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-55, 35))
# Out:
# The r-value is 1.8714628571117828e-05

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (0, 14))
# Out:
# The r-value is 0.00239442385677805

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-23, 17.5))
# Out:
# The r-value is 0.0738036523792996

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
